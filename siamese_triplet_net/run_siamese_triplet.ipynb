# %% [markdown]
# # Code for running SiameseNet and TripletNet on BRACOL Dataset
#
# ***The code used in this notebook is mostly from [this](https://github.com/adambielski/siamese-triplet/). If you are interested in it, check it out, it is extremely well documented***

# %% [markdown]
# ***Install libs***

# %%
# !pip install learn2learn
# !pip install efficientnet_pytorch

from IPython.display import clear_output 
clear_output()

print('Done!')
# Out:
# Done!

# %% [markdown]
# ***Import some libs***

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/pg/siamese_triplet_net/src/')
import torch
device = torch.cuda.is_available()
from dataloaders import get_train_transforms, get_val_transforms, get_siamese_dataloader, get_triplet_dataloader
from networks import SiameseNet, TripletNet 
from models import *
from losses import ContrastiveLoss, TripletLoss
from trainer import fit
import torchvision

# %% [markdown]
# ***Define model hiperparams***

# %%
# model & optimizer & lr_scheduler
embedding_net = MobileNetv2()
model = TripletNet(embedding_net=embedding_net)

optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)
loss_fn = TripletLoss(1.)
n_epochs=100

if device:
    model.cuda()

log_interval = 100

# path to data
path_data = '/content/drive/MyDrive/pg/dataset/'

# define siamese train and val loaders
# this loader is implemented for datasets in ImageFolder format (https://pytorch.org/vision/stable/datasets.html#imagefolder)
triplet_train_loader = get_triplet_dataloader(root=path_data + '/train/', batch_size=32, transforms=get_train_transforms())
triplet_val_loader = get_triplet_dataloader(root=path_data + '/val/', batch_size=32, transforms=get_val_transforms())

# %%
fit(triplet_train_loader, triplet_val_loader, model, loss_fn, optimizer, lr_scheduler, n_epochs, device, log_interval)
# Out:
# Train: [0/1539 (0%)]	Loss: 0.923412
# Epoch: 1/100. Train set: Average loss: 0.8433
# Epoch: 1/100. Validation set: Average loss: 0.6843
# Estimated time of epoch: 46.43 s
# ETA:77.38 min
# Train: [0/1539 (0%)]	Loss: 0.722344
# Epoch: 2/100. Train set: Average loss: 0.5798
# Epoch: 2/100. Validation set: Average loss: 0.3653
# Estimated time of epoch: 46.33 s
# ETA:76.44 min
# Train: [0/1539 (0%)]	Loss: 0.278118
# Epoch: 3/100. Train set: Average loss: 0.3377
# Epoch: 3/100. Validation set: Average loss: 0.2400
# Estimated time of epoch: 46.19 s
# ETA:75.44 min
# Train: [0/1539 (0%)]	Loss: 0.290723
# Epoch: 4/100. Train set: Average loss: 0.2668
# Epoch: 4/100. Validation set: Average loss: 0.1888
# Estimated time of epoch: 45.99 s
# ETA:74.35 min
# Train: [0/1539 (0%)]	Loss: 0.228033
# Epoch: 5/100. Train set: Average loss: 0.1921
# Epoch: 5/100. Validation set: Average loss: 0.1034
# Estimated time of epoch: 46.18 s
# ETA:73.89 min
# Train: [0/1539 (0%)]	Loss: 0.181840
# Epoch: 6/100. Train set: Average loss: 0.1678
# Epoch: 6/100. Validation set: Average loss: 0.0773
# Estimated time of epoch: 46.3 s
# ETA:73.31 min
# Train: [0/1539 (0%)]	Loss: 0.075763
# Epoch: 7/100. Train set: Average loss: 0.1343
# Epoch: 7/100. Validation set: Average loss: 0.0854
# Estimated time of epoch: 46.08 s
# ETA:72.19 min
# Train: [0/1539 (0%)]	Loss: 0.054339
# Epoch: 8/100. Train set: Average loss: 0.1268
# Epoch: 8/100. Validation set: Average loss: 0.0620
# Estimated time of epoch: 46.15 s
# ETA:71.53 min
# Train: [0/1539 (0%)]	Loss: 0.085077
# Epoch: 9/100. Train set: Average loss: 0.1022
# Epoch: 9/100. Validation set: Average loss: 0.0704
# Estimated time of epoch: 46.12 s
# ETA:70.72 min
# Train: [0/1539 (0%)]	Loss: 0.039801
# Epoch: 10/100. Train set: Average loss: 0.1010
# Epoch: 10/100. Validation set: Average loss: 0.0455
# Estimated time of epoch: 46.05 s
# ETA:69.84 min
# Train: [0/1539 (0%)]	Loss: 0.148998
# Epoch: 11/100. Train set: Average loss: 0.0902
# Epoch: 11/100. Validation set: Average loss: 0.0452
# Estimated time of epoch: 45.53 s
# ETA:68.3 min
# Train: [0/1539 (0%)]	Loss: 0.090480
# Epoch: 12/100. Train set: Average loss: 0.0790
# Epoch: 12/100. Validation set: Average loss: 0.0546
# Estimated time of epoch: 45.97 s
# ETA:68.19 min
# Train: [0/1539 (0%)]	Loss: 0.218285
# Epoch: 13/100. Train set: Average loss: 0.0748
# Epoch: 13/100. Validation set: Average loss: 0.0562
# Estimated time of epoch: 45.84 s
# ETA:67.23 min
# Train: [0/1539 (0%)]	Loss: 0.088770
# Epoch: 14/100. Train set: Average loss: 0.0702
# Epoch: 14/100. Validation set: Average loss: 0.0570
# Estimated time of epoch: 45.69 s
# ETA:66.25 min
# Train: [0/1539 (0%)]	Loss: 0.029661
# Epoch: 15/100. Train set: Average loss: 0.0778
# Epoch: 15/100. Validation set: Average loss: 0.0536
# Estimated time of epoch: 45.2 s
# ETA:64.79 min
# Train: [0/1539 (0%)]	Loss: 0.067782
# Epoch: 16/100. Train set: Average loss: 0.0573
# Epoch: 16/100. Validation set: Average loss: 0.0335
# Estimated time of epoch: 45.32 s
# ETA:64.2 min
# Train: [0/1539 (0%)]	Loss: 0.080594
# Epoch: 17/100. Train set: Average loss: 0.0611
# Epoch: 17/100. Validation set: Average loss: 0.0494
# Estimated time of epoch: 45.42 s
# ETA:63.59 min
# Train: [0/1539 (0%)]	Loss: 0.017350
# Epoch: 18/100. Train set: Average loss: 0.0621
# Epoch: 18/100. Validation set: Average loss: 0.0421
# Estimated time of epoch: 45.12 s
# ETA:62.42 min
# Train: [0/1539 (0%)]	Loss: 0.021163
# Epoch: 19/100. Train set: Average loss: 0.0512
# Epoch: 19/100. Validation set: Average loss: 0.0502
# Estimated time of epoch: 45.49 s
# ETA:62.17 min
# Train: [0/1539 (0%)]	Loss: 0.054344
# Epoch: 20/100. Train set: Average loss: 0.0459
# Epoch: 20/100. Validation set: Average loss: 0.0435
# Estimated time of epoch: 45.35 s
# ETA:61.22 min
# Train: [0/1539 (0%)]	Loss: 0.139589
# Epoch: 21/100. Train set: Average loss: 0.0597
# Epoch: 21/100. Validation set: Average loss: 0.0404
# Estimated time of epoch: 45.58 s
# ETA:60.77 min
# Train: [0/1539 (0%)]	Loss: 0.006960
# Epoch: 22/100. Train set: Average loss: 0.0545
# Epoch: 22/100. Validation set: Average loss: 0.0322
# Estimated time of epoch: 45.05 s
# ETA:59.32 min
# Train: [0/1539 (0%)]	Loss: 0.070593
# Epoch: 23/100. Train set: Average loss: 0.0497
# Epoch: 23/100. Validation set: Average loss: 0.0349
# Estimated time of epoch: 45.47 s
# ETA:59.11 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 24/100. Train set: Average loss: 0.0429
# Epoch: 24/100. Validation set: Average loss: 0.0601
# Estimated time of epoch: 45.69 s
# ETA:58.64 min
# Train: [0/1539 (0%)]	Loss: 0.007314
# Epoch: 25/100. Train set: Average loss: 0.0391
# Epoch: 25/100. Validation set: Average loss: 0.0537
# Estimated time of epoch: 46.11 s
# ETA:58.41 min
# Train: [0/1539 (0%)]	Loss: 0.051371
# Epoch: 26/100. Train set: Average loss: 0.0463
# Epoch: 26/100. Validation set: Average loss: 0.0379
# Estimated time of epoch: 45.54 s
# ETA:56.92 min
# Train: [0/1539 (0%)]	Loss: 0.023890
# Epoch: 27/100. Train set: Average loss: 0.0376
# Epoch: 27/100. Validation set: Average loss: 0.0712
# Estimated time of epoch: 45.71 s
# ETA:56.38 min
# Train: [0/1539 (0%)]	Loss: 0.051617
# Epoch: 28/100. Train set: Average loss: 0.0364
# Epoch: 28/100. Validation set: Average loss: 0.0518
# Estimated time of epoch: 45.85 s
# ETA:55.78 min
# Train: [0/1539 (0%)]	Loss: 0.107476
# Epoch: 29/100. Train set: Average loss: 0.0439
# Epoch: 29/100. Validation set: Average loss: 0.0349
# Estimated time of epoch: 45.66 s
# ETA:54.79 min
# Train: [0/1539 (0%)]	Loss: 0.022157
# Epoch: 30/100. Train set: Average loss: 0.0464
# Epoch: 30/100. Validation set: Average loss: 0.0385
# Estimated time of epoch: 45.77 s
# ETA:54.16 min
# Train: [0/1539 (0%)]	Loss: 0.029939
# Epoch: 31/100. Train set: Average loss: 0.0319
# Epoch: 31/100. Validation set: Average loss: 0.0282
# Estimated time of epoch: 45.92 s
# ETA:53.57 min
# Train: [0/1539 (0%)]	Loss: 0.025794
# Epoch: 32/100. Train set: Average loss: 0.0265
# Epoch: 32/100. Validation set: Average loss: 0.0439
# Estimated time of epoch: 45.63 s
# ETA:52.47 min
# Train: [0/1539 (0%)]	Loss: 0.006787
# Epoch: 33/100. Train set: Average loss: 0.0402
# Epoch: 33/100. Validation set: Average loss: 0.0477
# Estimated time of epoch: 46.04 s
# ETA:52.18 min
# Train: [0/1539 (0%)]	Loss: 0.021872
# Epoch: 34/100. Train set: Average loss: 0.0409
# Epoch: 34/100. Validation set: Average loss: 0.0397
# Estimated time of epoch: 45.44 s
# ETA:50.74 min
# Train: [0/1539 (0%)]	Loss: 0.016758
# Epoch: 35/100. Train set: Average loss: 0.0355
# Epoch: 35/100. Validation set: Average loss: 0.0351
# Estimated time of epoch: 46.15 s
# ETA:50.77 min
# Train: [0/1539 (0%)]	Loss: 0.014562
# Epoch: 36/100. Train set: Average loss: 0.0347
# Epoch: 36/100. Validation set: Average loss: 0.0437
# Estimated time of epoch: 45.39 s
# ETA:49.17 min
# Train: [0/1539 (0%)]	Loss: 0.078658
# Epoch: 37/100. Train set: Average loss: 0.0230
# Epoch: 37/100. Validation set: Average loss: 0.0358
# Estimated time of epoch: 45.13 s
# ETA:48.14 min
# Train: [0/1539 (0%)]	Loss: 0.000229
# Epoch: 38/100. Train set: Average loss: 0.0354
# Epoch: 38/100. Validation set: Average loss: 0.0265
# Estimated time of epoch: 45.54 s
# ETA:47.82 min
# Train: [0/1539 (0%)]	Loss: 0.027989
# Epoch: 39/100. Train set: Average loss: 0.0324
# Epoch: 39/100. Validation set: Average loss: 0.0355
# Estimated time of epoch: 44.9 s
# ETA:46.4 min
# Train: [0/1539 (0%)]	Loss: 0.018823
# Epoch: 40/100. Train set: Average loss: 0.0392
# Epoch: 40/100. Validation set: Average loss: 0.0554
# Estimated time of epoch: 44.94 s
# ETA:45.69 min
# Train: [0/1539 (0%)]	Loss: 0.006706
# Epoch: 41/100. Train set: Average loss: 0.0252
# Epoch: 41/100. Validation set: Average loss: 0.0302
# Estimated time of epoch: 44.85 s
# ETA:44.85 min
# Train: [0/1539 (0%)]	Loss: 0.010746
# Epoch: 42/100. Train set: Average loss: 0.0378
# Epoch: 42/100. Validation set: Average loss: 0.0365
# Estimated time of epoch: 45.3 s
# ETA:44.54 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 43/100. Train set: Average loss: 0.0376
# Epoch: 43/100. Validation set: Average loss: 0.0322
# Estimated time of epoch: 44.82 s
# ETA:43.33 min
# Train: [0/1539 (0%)]	Loss: 0.009602
# Epoch: 44/100. Train set: Average loss: 0.0279
# Epoch: 44/100. Validation set: Average loss: 0.0350
# Estimated time of epoch: 44.68 s
# ETA:42.45 min
# Train: [0/1539 (0%)]	Loss: 0.003805
# Epoch: 45/100. Train set: Average loss: 0.0277
# Epoch: 45/100. Validation set: Average loss: 0.0261
# Estimated time of epoch: 44.4 s
# ETA:41.44 min
# Train: [0/1539 (0%)]	Loss: 0.032734
# Epoch: 46/100. Train set: Average loss: 0.0289
# Epoch: 46/100. Validation set: Average loss: 0.0248
# Estimated time of epoch: 45.13 s
# ETA:41.37 min
# Train: [0/1539 (0%)]	Loss: 0.053583
# Epoch: 47/100. Train set: Average loss: 0.0376
# Epoch: 47/100. Validation set: Average loss: 0.0580
# Estimated time of epoch: 44.91 s
# ETA:40.42 min
# Train: [0/1539 (0%)]	Loss: 0.020195
# Epoch: 48/100. Train set: Average loss: 0.0216
# Epoch: 48/100. Validation set: Average loss: 0.0340
# Estimated time of epoch: 44.53 s
# ETA:39.33 min
# Train: [0/1539 (0%)]	Loss: 0.026045
# Epoch: 49/100. Train set: Average loss: 0.0289
# Epoch: 49/100. Validation set: Average loss: 0.0476
# Estimated time of epoch: 45.16 s
# ETA:39.14 min
# Train: [0/1539 (0%)]	Loss: 0.002393
# Epoch: 50/100. Train set: Average loss: 0.0357
# Epoch: 50/100. Validation set: Average loss: 0.0470
# Estimated time of epoch: 44.37 s
# ETA:37.71 min
# Train: [0/1539 (0%)]	Loss: 0.013701
# Epoch: 51/100. Train set: Average loss: 0.0255
# Epoch: 51/100. Validation set: Average loss: 0.0321
# Estimated time of epoch: 44.21 s
# ETA:36.84 min
# Train: [0/1539 (0%)]	Loss: 0.003406
# Epoch: 52/100. Train set: Average loss: 0.0283
# Epoch: 52/100. Validation set: Average loss: 0.0407
# Estimated time of epoch: 44.59 s
# ETA:36.42 min
# Train: [0/1539 (0%)]	Loss: 0.028427
# Epoch: 53/100. Train set: Average loss: 0.0200
# Epoch: 53/100. Validation set: Average loss: 0.0344
# Estimated time of epoch: 44.95 s
# ETA:35.96 min
# Train: [0/1539 (0%)]	Loss: 0.010608
# Epoch: 54/100. Train set: Average loss: 0.0159
# Epoch: 54/100. Validation set: Average loss: 0.0398
# Estimated time of epoch: 44.21 s
# ETA:34.63 min
# Train: [0/1539 (0%)]	Loss: 0.001048
# Epoch: 55/100. Train set: Average loss: 0.0289
# Epoch: 55/100. Validation set: Average loss: 0.0430
# Estimated time of epoch: 44.24 s
# ETA:33.92 min
# Train: [0/1539 (0%)]	Loss: 0.000689
# Epoch: 56/100. Train set: Average loss: 0.0288
# Epoch: 56/100. Validation set: Average loss: 0.0251
# Estimated time of epoch: 44.37 s
# ETA:33.28 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 57/100. Train set: Average loss: 0.0261
# Epoch: 57/100. Validation set: Average loss: 0.0385
# Estimated time of epoch: 44.73 s
# ETA:32.8 min
# Train: [0/1539 (0%)]	Loss: 0.007668
# Epoch: 58/100. Train set: Average loss: 0.0184
# Epoch: 58/100. Validation set: Average loss: 0.0387
# Estimated time of epoch: 44.11 s
# ETA:31.61 min
# Train: [0/1539 (0%)]	Loss: 0.043065
# Epoch: 59/100. Train set: Average loss: 0.0435
# Epoch: 59/100. Validation set: Average loss: 0.0252
# Estimated time of epoch: 44.41 s
# ETA:31.09 min
# Train: [0/1539 (0%)]	Loss: 0.021968
# Epoch: 60/100. Train set: Average loss: 0.0193
# Epoch: 60/100. Validation set: Average loss: 0.0346
# Estimated time of epoch: 44.96 s
# ETA:30.72 min
# Train: [0/1539 (0%)]	Loss: 0.000457
# Epoch: 61/100. Train set: Average loss: 0.0207
# Epoch: 61/100. Validation set: Average loss: 0.0531
# Estimated time of epoch: 44.18 s
# ETA:29.45 min
# Train: [0/1539 (0%)]	Loss: 0.008665
# Epoch: 62/100. Train set: Average loss: 0.0260
# Epoch: 62/100. Validation set: Average loss: 0.0402
# Estimated time of epoch: 44.97 s
# ETA:29.23 min
# Train: [0/1539 (0%)]	Loss: 0.030195
# Epoch: 63/100. Train set: Average loss: 0.0292
# Epoch: 63/100. Validation set: Average loss: 0.0253
# Estimated time of epoch: 44.51 s
# ETA:28.19 min
# Train: [0/1539 (0%)]	Loss: 0.000216
# Epoch: 64/100. Train set: Average loss: 0.0439
# Epoch: 64/100. Validation set: Average loss: 0.0366
# Estimated time of epoch: 44.73 s
# ETA:27.58 min
# Train: [0/1539 (0%)]	Loss: 0.019076
# Epoch: 65/100. Train set: Average loss: 0.0257
# Epoch: 65/100. Validation set: Average loss: 0.0286
# Estimated time of epoch: 44.3 s
# ETA:26.58 min
# Train: [0/1539 (0%)]	Loss: 0.005285
# Epoch: 66/100. Train set: Average loss: 0.0218
# Epoch: 66/100. Validation set: Average loss: 0.0310
# Estimated time of epoch: 44.64 s
# ETA:26.04 min
# Train: [0/1539 (0%)]	Loss: 0.039320
# Epoch: 67/100. Train set: Average loss: 0.0237
# Epoch: 67/100. Validation set: Average loss: 0.0444
# Estimated time of epoch: 44.65 s
# ETA:25.3 min
# Train: [0/1539 (0%)]	Loss: 0.074760
# Epoch: 68/100. Train set: Average loss: 0.0245
# Epoch: 68/100. Validation set: Average loss: 0.0444
# Estimated time of epoch: 44.67 s
# ETA:24.57 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 69/100. Train set: Average loss: 0.0228
# Epoch: 69/100. Validation set: Average loss: 0.0409
# Estimated time of epoch: 45.13 s
# ETA:24.07 min
# Train: [0/1539 (0%)]	Loss: 0.001076
# Epoch: 70/100. Train set: Average loss: 0.0438
# Epoch: 70/100. Validation set: Average loss: 0.0517
# Estimated time of epoch: 44.43 s
# ETA:22.96 min
# Train: [0/1539 (0%)]	Loss: 0.050151
# Epoch: 71/100. Train set: Average loss: 0.0156
# Epoch: 71/100. Validation set: Average loss: 0.0410
# Estimated time of epoch: 44.36 s
# ETA:22.18 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 72/100. Train set: Average loss: 0.0255
# Epoch: 72/100. Validation set: Average loss: 0.0312
# Estimated time of epoch: 44.82 s
# ETA:21.66 min
# Train: [0/1539 (0%)]	Loss: 0.006716
# Epoch: 73/100. Train set: Average loss: 0.0357
# Epoch: 73/100. Validation set: Average loss: 0.0355
# Estimated time of epoch: 45.17 s
# ETA:21.08 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 74/100. Train set: Average loss: 0.0193
# Epoch: 74/100. Validation set: Average loss: 0.0333
# Estimated time of epoch: 45.74 s
# ETA:20.58 min
# Train: [0/1539 (0%)]	Loss: 0.003843
# Epoch: 75/100. Train set: Average loss: 0.0359
# Epoch: 75/100. Validation set: Average loss: 0.0363
# Estimated time of epoch: 45.35 s
# ETA:19.65 min
# Train: [0/1539 (0%)]	Loss: 0.034670
# Epoch: 76/100. Train set: Average loss: 0.0248
# Epoch: 76/100. Validation set: Average loss: 0.0505
# Estimated time of epoch: 45.89 s
# ETA:19.12 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 77/100. Train set: Average loss: 0.0284
# Epoch: 77/100. Validation set: Average loss: 0.0292
# Estimated time of epoch: 45.83 s
# ETA:18.33 min
# Train: [0/1539 (0%)]	Loss: 0.006065
# Epoch: 78/100. Train set: Average loss: 0.0226
# Epoch: 78/100. Validation set: Average loss: 0.0341
# Estimated time of epoch: 45.85 s
# ETA:17.58 min
# Train: [0/1539 (0%)]	Loss: 0.095525
# Epoch: 79/100. Train set: Average loss: 0.0166
# Epoch: 79/100. Validation set: Average loss: 0.0341
# Estimated time of epoch: 46.13 s
# ETA:16.91 min
# Train: [0/1539 (0%)]	Loss: 0.013796
# Epoch: 80/100. Train set: Average loss: 0.0358
# Epoch: 80/100. Validation set: Average loss: 0.0233
# Estimated time of epoch: 46.47 s
# ETA:16.26 min
# Train: [0/1539 (0%)]	Loss: 0.035516
# Epoch: 81/100. Train set: Average loss: 0.0353
# Epoch: 81/100. Validation set: Average loss: 0.0322
# Estimated time of epoch: 46.23 s
# ETA:15.41 min
# Train: [0/1539 (0%)]	Loss: 0.037209
# Epoch: 82/100. Train set: Average loss: 0.0170
# Epoch: 82/100. Validation set: Average loss: 0.0341
# Estimated time of epoch: 45.83 s
# ETA:14.51 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 83/100. Train set: Average loss: 0.0205
# Epoch: 83/100. Validation set: Average loss: 0.0297
# Estimated time of epoch: 46.1 s
# ETA:13.83 min
# Train: [0/1539 (0%)]	Loss: 0.004735
# Epoch: 84/100. Train set: Average loss: 0.0211
# Epoch: 84/100. Validation set: Average loss: 0.0818
# Estimated time of epoch: 46.45 s
# ETA:13.16 min
# Train: [0/1539 (0%)]	Loss: 0.003021
# Epoch: 85/100. Train set: Average loss: 0.0162
# Epoch: 85/100. Validation set: Average loss: 0.0473
# Estimated time of epoch: 46.32 s
# ETA:12.35 min
# Train: [0/1539 (0%)]	Loss: 0.000412
# Epoch: 86/100. Train set: Average loss: 0.0294
# Epoch: 86/100. Validation set: Average loss: 0.0545
# Estimated time of epoch: 46.04 s
# ETA:11.51 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 87/100. Train set: Average loss: 0.0306
# Epoch: 87/100. Validation set: Average loss: 0.0386
# Estimated time of epoch: 45.76 s
# ETA:10.68 min
# Train: [0/1539 (0%)]	Loss: 0.001840
# Epoch: 88/100. Train set: Average loss: 0.0183
# Epoch: 88/100. Validation set: Average loss: 0.0300
# Estimated time of epoch: 46.11 s
# ETA:9.99 min
# Train: [0/1539 (0%)]	Loss: 0.020517
# Epoch: 89/100. Train set: Average loss: 0.0191
# Epoch: 89/100. Validation set: Average loss: 0.0319
# Estimated time of epoch: 46.28 s
# ETA:9.26 min
# Train: [0/1539 (0%)]	Loss: 0.065169
# Epoch: 90/100. Train set: Average loss: 0.0187
# Epoch: 90/100. Validation set: Average loss: 0.0542
# Estimated time of epoch: 45.91 s
# ETA:8.42 min
# Train: [0/1539 (0%)]	Loss: 0.022093
# Epoch: 91/100. Train set: Average loss: 0.0134
# Epoch: 91/100. Validation set: Average loss: 0.0273
# Estimated time of epoch: 45.51 s
# ETA:7.58 min
# Train: [0/1539 (0%)]	Loss: 0.040742
# Epoch: 92/100. Train set: Average loss: 0.0320
# Epoch: 92/100. Validation set: Average loss: 0.0308
# Estimated time of epoch: 46.22 s
# ETA:6.93 min
# Train: [0/1539 (0%)]	Loss: 0.019911
# Epoch: 93/100. Train set: Average loss: 0.0227
# Epoch: 93/100. Validation set: Average loss: 0.0279
# Estimated time of epoch: 46.33 s
# ETA:6.18 min
# Train: [0/1539 (0%)]	Loss: 0.118242
# Epoch: 94/100. Train set: Average loss: 0.0254
# Epoch: 94/100. Validation set: Average loss: 0.0456
# Estimated time of epoch: 45.95 s
# ETA:5.36 min
# Train: [0/1539 (0%)]	Loss: 0.002514
# Epoch: 95/100. Train set: Average loss: 0.0253
# Epoch: 95/100. Validation set: Average loss: 0.0466
# Estimated time of epoch: 45.99 s
# ETA:4.6 min
# Train: [0/1539 (0%)]	Loss: 0.006527
# Epoch: 96/100. Train set: Average loss: 0.0106
# Epoch: 96/100. Validation set: Average loss: 0.0462
# Estimated time of epoch: 45.8 s
# ETA:3.82 min
# Train: [0/1539 (0%)]	Loss: 0.003691
# Epoch: 97/100. Train set: Average loss: 0.0180
# Epoch: 97/100. Validation set: Average loss: 0.0438
# Estimated time of epoch: 45.69 s
# ETA:3.05 min
# Train: [0/1539 (0%)]	Loss: 0.000000
# Epoch: 98/100. Train set: Average loss: 0.0282
# Epoch: 98/100. Validation set: Average loss: 0.0337
# Estimated time of epoch: 45.8 s
# ETA:2.29 min
# Train: [0/1539 (0%)]	Loss: 0.043150
# Epoch: 99/100. Train set: Average loss: 0.0334
# Epoch: 99/100. Validation set: Average loss: 0.0374
# Estimated time of epoch: 45.67 s
# ETA:1.52 min
# Train: [0/1539 (0%)]	Loss: 0.037828
# Epoch: 100/100. Train set: Average loss: 0.0240
# Epoch: 100/100. Validation set: Average loss: 0.0380
# Estimated time of epoch: 46.03 s
# ETA:0.77 min

# %%
# from: https://github.com/avilash/pytorch-siamese-triplet/blob/master/tsne.py
import cv2
import numpy as np
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
from tqdm import tqdm
from torchvision import transforms
from torch.autograd import Variable
import os
import pandas as pd
import seaborn as sns
def generate_embeddings(data_loader, model):
    with torch.no_grad():
        device = 'cuda'
        model.eval()
        model.to(device)
        labels = None
        embeddings = None
        for batch_idx, data in tqdm(enumerate(data_loader)):
            batch_imgs, batch_labels = data
            batch_labels = batch_labels.numpy()
            batch_imgs = Variable(batch_imgs.to('cuda'))
            batch_E = model.get_embedding(batch_imgs)
            batch_E = batch_E.data.cpu().numpy()
            embeddings = np.concatenate((embeddings, batch_E), axis=0) if embeddings is not None else batch_E
            labels = np.concatenate((labels, batch_labels), axis=0) if labels is not None else batch_labels
    return embeddings, labels

def vis_tSNE(embeddings, labels, backbone='Convnet'):
    num_samples = embeddings.shape[0]
    X_embedded = TSNE(n_components=2).fit_transform(embeddings[0:num_samples, :])
    plt.figure(figsize=(16, 16))
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']
    labels_name = ['Healthy', 'Miner', 'Rust', 'Phoma', 'Cercospora']
    for i in range(5):
        inds = np.where(labels==i)[0]
        plt.scatter(X_embedded[inds,0], X_embedded[inds,1], alpha=.8, color=colors[i], s=200)
    # plt.title(f't-SNE', fontweight='bold', fontsize=24)
    plt.legend(labels_name, fontsize=30)
    plt.savefig(f'./tsne_{backbone}.png')

# %%
test_data = torchvision.datasets.ImageFolder(root=path_data + '/test/', transform=get_val_transforms())
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1)

val_embeddings_cl, val_labels_cl = generate_embeddings(test_loader, model)
vis_tSNE(val_embeddings_cl, val_labels_cl)
# Out:
# 66it [00:00, 104.09it/s]

# %%
train_data = torchvision.datasets.ImageFolder(root=path_data + '/train/', transform=get_val_transforms())
train_loader = torch.utils.data.DataLoader(train_data, batch_size=32)

test_data = torchvision.datasets.ImageFolder(root=path_data + '/test/', transform=get_val_transforms())
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32)

x_train, y_train = generate_embeddings(train_loader, model)
x_test, y_true = generate_embeddings(test_loader, model)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier

classifier = KNeighborsClassifier(n_neighbors=1)
# classifier = SVC()
# classifier = SGDClassifier()
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)

accuracy = round(accuracy_score(y_true, y_pred)*100, 2)
precision = round(precision_score(y_true, y_pred, average='macro')*100, 2)
recall = round(recall_score(y_true, y_pred, average='macro')*100, 2)
f1 = round(f1_score(y_true, y_pred, average='macro')*100, 2)
print(f'--- Results for MobileNetv2 Embeddings on KNN (k = 1) ---')
print(f'Accuracy Score:{accuracy}')
print(f'Precision Score: {precision}')
print(f'Recall Score: {recall}')
print(f'F1 Score: {f1}')
# Out:
# 49it [00:07,  6.34it/s]
# 11it [00:01,  6.70it/s]
# --- Results for MobileNetv2 Embeddings on KNN (k = 1) ---
# Accuracy Score:96.12
# Precision Score: 96.08
# Recall Score: 95.87
# F1 Score: 95.96
